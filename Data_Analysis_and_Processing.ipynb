# %% [markdown]
# <a href="https://colab.research.google.com/github/vvrgit/FDP-NNDL/blob/main/Data_Analysis_and_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load Required Libraries

# %%
import pandas as pd # For Data manipulation
import numpy as np
import missingno as msno

# %% [markdown]
# #Load Data

# %%
load_data_nan=pd.read_excel("/content/drive/MyDrive/NNDL-Data/Load_nan.xlsx")
load_data_nan.head()
# Out:
#     L(T-1)   L(T-2)  L(T-24)  L(T-48)   P(T-1)   P(T-2)  P(T-24)  P(T-48)  \
# 0  4851.90  4309.93  5257.03  4574.50  2313.77  2333.89  2328.34  2285.62
# 1  5604.93  4851.90  5527.90      NaN  2005.82  2313.77  2143.30  2097.21
# 2  6012.75      NaN  5820.83  5314.53  1886.45  2005.82  2024.52  2008.19
# 3  6163.53  6012.75  5910.98  5471.73  1810.42  1886.45  1942.67  2008.32
# 4  6310.30  6163.53  6189.18  5974.50  1805.42      NaN  2071.41  2038.73
#
#    Day  Season     L(T)
# 0  1.0     2.0  5604.93
# 1  1.0     2.0  6012.75
# 2  1.0     2.0  6163.53
# 3  NaN     2.0  6310.30
# 4  1.0     2.0  6606.13

# %% [markdown]
# #Statistical Analysis

# %%
load_data_nan.describe()
# Out:
#              L(T-1)        L(T-2)       L(T-24)       L(T-48)       P(T-1)  \
# count  9.500000e+01     93.000000  9.000000e+01  9.200000e+01    96.000000
# mean   1.808490e+04   7649.527957  1.863412e+04  1.809998e+04  2953.778229
# std    1.018731e+05   1933.661473  1.046468e+05  1.035265e+05  1042.328070
# min    3.968730e+03   3968.730000  3.968730e+03  3.791880e+03  1560.900000
# 25%    5.831140e+03   5835.200000  5.888280e+03  5.825517e+03  2002.600000
# 50%    7.878490e+03   7878.490000  7.770410e+03  7.488280e+03  2952.955000
# 75%    9.360650e+03   9371.180000  9.266908e+03  8.678487e+03  3662.100000
# max    1.000399e+06  10860.020000  1.000218e+06  1.000153e+06  5947.600000
#
#             P(T-2)      P(T-24)        P(T-48)         Day  Season  \
# count    91.000000    92.000000      96.000000   93.000000    91.0
# mean   2933.717802  3048.101739    6116.383958    1.311828     2.0
# std    1047.122922  1158.514614   30333.645074   10.353511     0.0
# ...

# %% [markdown]
# #Null Value Information

# %%
load_data_nan.isnull().sum()
# Out:
# L(T-1)     4
# L(T-2)     6
# L(T-24)    9
# L(T-48)    7
# P(T-1)     3
# P(T-2)     8
# P(T-24)    7
# P(T-48)    3
# Day        6
# Season     8
# L(T)       7
# dtype: int64

# %%
load_data_nan.isnull().any()
# Out:
# L(T-1)     True
# L(T-2)     True
# L(T-24)    True
# L(T-48)    True
# P(T-1)     True
# P(T-2)     True
# P(T-24)    True
# P(T-48)    True
# Day        True
# Season     True
# L(T)       True
# dtype: bool

# %%
msno.bar(load_data_nan)
# Out:
# <Axes: >

# %%
msno.matrix(load_data_nan)
# Out:
# <Axes: >

# %%
msno.heatmap(load_data_nan)
# Out:
# <Axes: >

# %% [markdown]
# #Missing Value Imputation

# %%
load_data_ffill = load_data_nan.fillna(method='ffill')
load_data_ffill.head()
# Out:
#     L(T-1)   L(T-2)  L(T-24)  L(T-48)   P(T-1)   P(T-2)  P(T-24)  P(T-48)  \
# 0  4851.90  4309.93  5257.03  4574.50  2313.77  2333.89  2328.34  2285.62
# 1  5604.93  4851.90  5527.90  4574.50  2005.82  2313.77  2143.30  2097.21
# 2  6012.75  4851.90  5820.83  5314.53  1886.45  2005.82  2024.52  2008.19
# 3  6163.53  6012.75  5910.98  5471.73  1810.42  1886.45  1942.67  2008.32
# 4  6310.30  6163.53  6189.18  5974.50  1805.42  1886.45  2071.41  2038.73
#
#    Day  Season     L(T)
# 0  1.0     2.0  5604.93
# 1  1.0     2.0  6012.75
# 2  1.0     2.0  6163.53
# 3  1.0     2.0  6310.30
# 4  1.0     2.0  6606.13

# %%
load_data_ffill.isnull().any()
# Out:
# L(T-1)     False
# L(T-2)     False
# L(T-24)    False
# L(T-48)    False
# P(T-1)     False
# P(T-2)     False
# P(T-24)    False
# P(T-48)    False
# Day        False
# Season     False
# L(T)       False
# dtype: bool

# %%
load_data_ffill.isnull().sum()
# Out:
# L(T-1)     0
# L(T-2)     0
# L(T-24)    0
# L(T-48)    0
# P(T-1)     0
# P(T-2)     0
# P(T-24)    0
# P(T-48)    0
# Day        0
# Season     0
# L(T)       0
# dtype: int64

# %%
load_data_ffill.describe()
# Out:
#              L(T-1)        L(T-2)       L(T-24)       L(T-48)       P(T-1)  \
# count  9.900000e+01     99.000000  9.900000e+01  9.900000e+01    99.000000
# mean   1.767199e+04   7650.803535  1.758153e+04  1.737605e+04  2938.022525
# std    9.979370e+04   1949.965130  9.978369e+04  9.979696e+04  1045.465690
# min    3.968730e+03   3968.730000  3.968730e+03  3.791880e+03  1560.900000
# 25%    5.831140e+03   5831.140000  5.861520e+03  5.831140e+03  2001.225000
# 50%    7.878490e+03   7878.490000  7.711900e+03  7.514650e+03  2941.360000
# 75%    9.375980e+03   9360.650000  9.229870e+03  8.693925e+03  3668.650000
# max    1.000399e+06  10860.020000  1.000218e+06  1.000153e+06  5947.600000
#
#             P(T-2)      P(T-24)        P(T-48)         Day  Season  \
# count    99.000000    99.000000      99.000000   99.000000    99.0
# mean   2921.096263  3023.202323    6073.878081    1.252525     2.0
# std    1026.955459  1140.541836   29867.714759   10.034983     0.0
# ...

# %% [markdown]
# #Drop Row

# %%
load_data_nan_row = load_data_nan.dropna(axis=0)
load_data_nan_row.head()
# Out:
#       L(T-1)    L(T-2)  L(T-24)  L(T-48)   P(T-1)   P(T-2)  P(T-24)  P(T-48)  \
# 0    4851.90   4309.93  5257.03  4574.50  2313.77  2333.89  2328.34  2285.62
# 5    6606.13   6310.30  6729.88  6508.18  1953.64  1805.42  2394.49  2301.64
# 9   10860.02  10186.25  9164.70  8355.20  3937.08  3290.00  6600.56  6225.65
# 10  10066.85  10860.02  8598.35  8434.38  5377.61  3937.08  6325.49  5475.39
# 11   9423.08  10066.85  7939.57  7714.90  3926.82  5377.61  5582.63  4500.57
#
#     Day  Season      L(T)
# 0   1.0     2.0   5604.93
# 5   1.0     2.0   7279.38
# 9   1.0     2.0  10066.85
# 10  1.0     2.0   9423.08
# 11  1.0     2.0   8588.13

# %%
load_data_nan_row.describe()
# Out:
#              L(T-1)        L(T-2)       L(T-24)       L(T-48)       P(T-1)  \
# count     48.000000     48.000000  4.800000e+01     48.000000    48.000000
# mean    7930.337500   7883.326250  2.843041e+04   7590.117917  3157.556667
# std     1820.483646   2012.551485  1.432588e+05   1644.368803  1159.280033
# min     4186.780000   3968.730000  4.762830e+03   4574.500000  1577.500000
# 25%     6538.510000   5873.970000  6.273608e+03   6125.835000  2007.432500
# 50%     8384.255000   8432.830000  7.913110e+03   7713.400000  3060.985000
# 75%     9384.077500   9433.690000  9.207995e+03   8808.185000  3929.385000
# max    10860.020000  10860.020000  1.000218e+06  10217.730000  5947.600000
#
#             P(T-2)      P(T-24)        P(T-48)        Day  Season  \
# count    48.000000    48.000000      48.000000  48.000000    48.0
# mean   3128.430625  3210.679583    9439.083958   0.208333     2.0
# std    1150.497361  1238.398361   42851.994202   0.410414     0.0
# ...

# %%
load_data_nan_row.isnull().any()
# Out:
# L(T-1)     False
# L(T-2)     False
# L(T-24)    False
# L(T-48)    False
# P(T-1)     False
# P(T-2)     False
# P(T-24)    False
# P(T-48)    False
# Day        False
# Season     False
# L(T)       False
# dtype: bool

# %%
load_data_nan_row.isnull().sum()
# Out:
# L(T-1)     0
# L(T-2)     0
# L(T-24)    0
# L(T-48)    0
# P(T-1)     0
# P(T-2)     0
# P(T-24)    0
# P(T-48)    0
# Day        0
# Season     0
# L(T)       0
# dtype: int64

# %% [markdown]
# #Drop Column

# %%
load_data_nan.isnull().sum()
# Out:
# L(T-1)     4
# L(T-2)     6
# L(T-24)    9
# L(T-48)    7
# P(T-1)     3
# P(T-2)     8
# P(T-24)    7
# P(T-48)    3
# Day        6
# Season     8
# L(T)       7
# dtype: int64

# %%
load_data_nan_col = load_data_nan.drop('L(T-24)', axis=1)

# %%
load_data_nan_col.describe()
# Out:
#              L(T-1)        L(T-2)       L(T-48)       P(T-1)       P(T-2)  \
# count  9.500000e+01     93.000000  9.200000e+01    96.000000    91.000000
# mean   1.808490e+04   7649.527957  1.809998e+04  2953.778229  2933.717802
# std    1.018731e+05   1933.661473  1.035265e+05  1042.328070  1047.122922
# min    3.968730e+03   3968.730000  3.791880e+03  1560.900000  1560.380000
# 25%    5.831140e+03   5835.200000  5.825517e+03  2002.600000  2002.590000
# 50%    7.878490e+03   7878.490000  7.488280e+03  2952.955000  2941.360000
# 75%    9.360650e+03   9371.180000  8.678487e+03  3662.100000  3635.180000
# max    1.000399e+06  10860.020000  1.000153e+06  5947.600000  5947.600000
#
#            P(T-24)        P(T-48)         Day  Season           L(T)
# count    92.000000      96.000000   93.000000    91.0      92.000000
# mean   3048.101739    6116.383958    1.311828     2.0   13029.311304
# std    1158.514614   30333.645074   10.353511     0.0   51393.894976
# ...

# %% [markdown]
# #Impute with mean

# %%
# column with mean of that column
load_data_nan['L(T-1)'] = load_data_nan['L(T-1)'].fillna(load_data_nan['L(T-1)'].mean())

# %%
load_data_nan.describe()
# Out:
#              L(T-1)        L(T-2)       L(T-24)       L(T-48)       P(T-1)  \
# count  9.900000e+01     93.000000  9.000000e+01  9.200000e+01    96.000000
# mean   1.808490e+04   7649.527957  1.863412e+04  1.809998e+04  2953.778229
# std    9.977239e+04   1933.661473  1.046468e+05  1.035265e+05  1042.328070
# min    3.968730e+03   3968.730000  3.968730e+03  3.791880e+03  1560.900000
# 25%    5.861520e+03   5835.200000  5.888280e+03  5.825517e+03  2002.600000
# 50%    7.964280e+03   7878.490000  7.770410e+03  7.488280e+03  2952.955000
# 75%    9.399435e+03   9371.180000  9.266908e+03  8.678487e+03  3662.100000
# max    1.000399e+06  10860.020000  1.000218e+06  1.000153e+06  5947.600000
#
#             P(T-2)      P(T-24)        P(T-48)         Day  Season  \
# count    91.000000    92.000000      96.000000   93.000000    91.0
# mean   2933.717802  3048.101739    6116.383958    1.311828     2.0
# std    1047.122922  1158.514614   30333.645074   10.353511     0.0
# ...

# %% [markdown]
# #Impute with median

# %%
# column with mean of that column
load_data_nan['L(T-2)'] = load_data_nan['L(T-2)'].fillna(load_data_nan['L(T-2)'].median())

# %%
load_data_nan.describe()
# Out:
#              L(T-1)        L(T-2)       L(T-24)       L(T-48)       P(T-1)  \
# count  9.900000e+01     99.000000  9.000000e+01  9.200000e+01    96.000000
# mean   1.808490e+04   7663.404444  1.863412e+04  1.809998e+04  2953.778229
# std    9.977239e+04   1874.337364  1.046468e+05  1.035265e+05  1042.328070
# min    3.968730e+03   3968.730000  3.968730e+03  3.791880e+03  1560.900000
# 25%    5.861520e+03   5888.720000  5.888280e+03  5.825517e+03  2002.600000
# 50%    7.964280e+03   7878.490000  7.770410e+03  7.488280e+03  2952.955000
# 75%    9.399435e+03   9342.185000  9.266908e+03  8.678487e+03  3662.100000
# max    1.000399e+06  10860.020000  1.000218e+06  1.000153e+06  5947.600000
#
#             P(T-2)      P(T-24)        P(T-48)         Day  Season  \
# count    91.000000    92.000000      96.000000   93.000000    91.0
# mean   2933.717802  3048.101739    6116.383958    1.311828     2.0
# std    1047.122922  1158.514614   30333.645074   10.353511     0.0
# ...

# %% [markdown]
# #Outlier Treatment Box Plot

# %%
load_data_nan_row.describe()
# Out:
#              L(T-1)        L(T-2)       L(T-24)       L(T-48)       P(T-1)  \
# count     48.000000     48.000000  4.800000e+01     48.000000    48.000000
# mean    7930.337500   7883.326250  2.843041e+04   7590.117917  3157.556667
# std     1820.483646   2012.551485  1.432588e+05   1644.368803  1159.280033
# min     4186.780000   3968.730000  4.762830e+03   4574.500000  1577.500000
# 25%     6538.510000   5873.970000  6.273608e+03   6125.835000  2007.432500
# 50%     8384.255000   8432.830000  7.913110e+03   7713.400000  3060.985000
# 75%     9384.077500   9433.690000  9.207995e+03   8808.185000  3929.385000
# max    10860.020000  10860.020000  1.000218e+06  10217.730000  5947.600000
#
#             P(T-2)      P(T-24)        P(T-48)        Day  Season  \
# count    48.000000    48.000000      48.000000  48.000000    48.0
# mean   3128.430625  3210.679583    9439.083958   0.208333     2.0
# std    1150.497361  1238.398361   42851.994202   0.410414     0.0
# ...

# %%
# Creating plot
plt.boxplot(load_data_nan_row)

# show plot
plt.show()

# %% [markdown]
# #Outlier Treatment based on Z-Score

# %%
def detect_outliers_zscore(data):
    outliers = []
    thres = 3
    mean = np.mean(data)
    std = np.std(data)
    #print(mean, std)
    for i in data:
        #print(i)
        z_score = (i-mean)/std
        if (np.abs(z_score) > thres):
            outliers.append(i)
    return outliers# Driver code

# %%
sample_outliers_LT1 = detect_outliers_zscore(load_data_nan_row['L(T-1)'])
print("Outliers in L(T-1) column from Z-scores method: ", sample_outliers_LT1)
sample_outliers_LT2 = detect_outliers_zscore(load_data_nan_row['L(T-2)'])
print("Outliers in L(T-2) column from Z-scores method: ", sample_outliers_LT2)
sample_outliers_LT24 = detect_outliers_zscore(load_data_nan_row['L(T-24)'])
print("Outliers in L(T-24) column from Z-scores method: ", sample_outliers_LT24)
sample_outliers_LT48 = detect_outliers_zscore(load_data_nan_row['L(T-48)'])
print("Outliers in L(T-48) column from Z-scores method: ", sample_outliers_LT48)

sample_outliers_PT1 = detect_outliers_zscore(load_data_nan_row['P(T-1)'])
print("Outliers in P(T-1) column from Z-scores method: ", sample_outliers_PT1)
sample_outliers_PT2 = detect_outliers_zscore(load_data_nan_row['P(T-2)'])
print("Outliers in P(T-2) column from Z-scores method: ", sample_outliers_PT2)
sample_outliers_PT24 = detect_outliers_zscore(load_data_nan_row['P(T-24)'])
print("Outliers in P(T-24) column from Z-scores method: ", sample_outliers_PT24)
sample_outliers_PT48 = detect_outliers_zscore(load_data_nan_row['P(T-48)'])
print("Outliers in P(T-48) column from Z-scores method: ", sample_outliers_PT48)


sample_outliers_day = detect_outliers_zscore(load_data_nan_row['Day'])
print("Outliers in day column from Z-scores method: ", sample_outliers_day)
#sample_outliers_season = detect_outliers_zscore(load_data_nan_row['Season'])
#print("Outliers in season column from Z-scores method: ", sample_outliers_season)
sample_outliers_LT = detect_outliers_zscore(load_data_nan_row['L(T)'])
print("Outliers in L(T) column from Z-scores method: ", sample_outliers_LT)
# Out:
# Outliers in L(T-1) column from Z-scores method:  []
# Outliers in L(T-2) column from Z-scores method:  []
# Outliers in L(T-24) column from Z-scores method:  [1000217.73]
# Outliers in L(T-48) column from Z-scores method:  []
# Outliers in P(T-1) column from Z-scores method:  []
# Outliers in P(T-2) column from Z-scores method:  []
# Outliers in P(T-24) column from Z-scores method:  []
# Outliers in P(T-48) column from Z-scores method:  [300030.31]
# Outliers in day column from Z-scores method:  []
# Outliers in L(T) column from Z-scores method:  [500312.4]

# %%
from scipy.stats import zscore
zLT1 = np.abs(zscore(load_data_nan_row['L(T-1)']))
zLT2 = np.abs(zscore(load_data_nan_row['L(T-2)']))
zLT24 = np.abs(zscore(load_data_nan_row['L(T-24)']))
zLT48 = np.abs(zscore(load_data_nan_row['L(T-48)']))


zPT1 = np.abs(zscore(load_data_nan_row['P(T-1)']))
zPT2 = np.abs(zscore(load_data_nan_row['P(T-2)']))
zPT24 = np.abs(zscore(load_data_nan_row['P(T-24)']))
zPT48 = np.abs(zscore(load_data_nan_row['P(T-48)']))

zDay = np.abs(zscore(load_data_nan_row['Day']))
#zSeason = np.abs(zscore(load_data_nan_row['Season']))
zLT = np.abs(zscore(load_data_nan_row['L(T)']))

load_data_nan_row['Zscore_L(T-1)'] = zLT1
load_data_nan_row['Zscore_L(T-2)'] = zLT2
load_data_nan_row['Zscore_L(T-24)'] = zLT24
load_data_nan_row['Zscore_L(T-48)'] = zLT48

load_data_nan_row['Zscore_P(T-1)'] = zPT1
load_data_nan_row['Zscore_P(T-2)'] = zPT2
load_data_nan_row['Zscore_P(T-24)'] = zPT24
load_data_nan_row['Zscore_P(T-48)'] = zPT48

load_data_nan_row['Zscore_Day'] = zDay
#load_data_nan_row['Zscore_Season'] = zSeason
load_data_nan_row['Zscore_LT'] = zLT

outliers_LT1=len(load_data_nan_row[load_data_nan_row['Zscore_L(T-1)']>3])
outliers_LT2=len(load_data_nan_row[load_data_nan_row['Zscore_L(T-2)']>3])
outliers_LT24=len(load_data_nan_row[load_data_nan_row['Zscore_L(T-24)']>3])
outliers_LT48=len(load_data_nan_row[load_data_nan_row['Zscore_L(T-48)']>3])

outliers_PT1=len(load_data_nan_row[load_data_nan_row['Zscore_P(T-1)']>3])
outliers_PT2=len(load_data_nan_row[load_data_nan_row['Zscore_P(T-2)']>3])
outliers_PT24=len(load_data_nan_row[load_data_nan_row['Zscore_P(T-24)']>3])
outliers_PT48=len(load_data_nan_row[load_data_nan_row['Zscore_P(T-48)']>3])

outliers_Day=len(load_data_nan_row[load_data_nan_row['Zscore_Day']>3])
#outliers_Season=len(load_data_nan_row[load_data_nan_row['Zscore_Season']>3])
outliers_LT=len(load_data_nan_row[load_data_nan_row['Zscore_LT']>3])
# Out:
# <ipython-input-222-fff70ce68de8>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   load_data_nan_row['Zscore_L(T-1)'] = zLT1
# <ipython-input-222-fff70ce68de8>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   load_data_nan_row['Zscore_L(T-2)'] = zLT2
# <ipython-input-222-fff70ce68de8>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
print("Outliers in L(T-1) column from Z-scores method: ", outliers_LT1)
print("Outliers in L(T-2) column from Z-scores method: ", outliers_LT2)
print("Outliers in L(T-24) column from Z-scores method: ", outliers_LT24)
print("Outliers in L(T-48) column from Z-scores method: ", outliers_LT48)
print("Outliers in P(T-1) column from Z-scores method: ", outliers_PT1)
print("Outliers in P(T-2) column from Z-scores method: ", outliers_PT2)
print("Outliers in P(T-24) column from Z-scores method: ", outliers_PT24)
print("Outliers in P(T-48) column from Z-scores method: ", outliers_PT48)
print("Outliers in day column from Z-scores method: ", outliers_Day)
#print("Outliers in season column from Z-scores method: ", outliers_Season)
print("Outliers in L(T) column from Z-scores method: ", outliers_LT)
# Out:
# Outliers in L(T-1) column from Z-scores method:  0
# Outliers in L(T-2) column from Z-scores method:  0
# Outliers in L(T-24) column from Z-scores method:  1
# Outliers in L(T-48) column from Z-scores method:  0
# Outliers in P(T-1) column from Z-scores method:  0
# Outliers in P(T-2) column from Z-scores method:  0
# Outliers in P(T-24) column from Z-scores method:  0
# Outliers in P(T-48) column from Z-scores method:  1
# Outliers in day column from Z-scores method:  0
# Outliers in L(T) column from Z-scores method:  1

# %%
load_data=load_data_nan_row[load_data_nan_row['Zscore_L(T-24)']<3]
load_data=load_data[load_data_nan_row['Zscore_P(T-48)']<3]
load_data=load_data[load_data_nan_row['Zscore_LT']<3]
load_data.describe()
# Out:
# <ipython-input-224-aca7889e98bc>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   load_data=load_data[load_data_nan_row['Zscore_P(T-48)']<3]
# <ipython-input-224-aca7889e98bc>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   load_data=load_data[load_data_nan_row['Zscore_LT']<3]
#              L(T-1)        L(T-2)       L(T-24)       L(T-48)       P(T-1)  \
# count     46.000000     46.000000     46.000000     46.000000    46.000000
# mean    7911.015435   7846.354130   7808.661304   7612.593696  3162.335435
# std     1849.131941   2046.185817   1593.738570   1603.149756  1184.313345
# min     4186.780000   3968.730000   4762.830000   4574.500000  1577.500000
# 25%     6403.270000   5842.710000   6415.195000   6249.692500  2007.397500
# 50%     8384.255000   8432.830000   7913.110000   7713.400000  3060.985000
# 75%     9390.672500   9454.910000   9190.035000   8759.810000  3934.515000
# ...

# %%
load_data=load_data.drop(['Zscore_L(T-1)', 'Zscore_L(T-2)', 'Zscore_L(T-24)', 'Zscore_L(T-48)', 'Zscore_P(T-1)', 'Zscore_P(T-2)', 'Zscore_P(T-24)', 'Zscore_P(T-48)', 'Zscore_Day',  'Zscore_LT'], axis=1)

# %%
load_data.head()
# Out:
#       L(T-1)    L(T-2)  L(T-24)  L(T-48)   P(T-1)   P(T-2)  P(T-24)  P(T-48)  \
# 0    4851.90   4309.93  5257.03  4574.50  2313.77  2333.89  2328.34  2285.62
# 5    6606.13   6310.30  6729.88  6508.18  1953.64  1805.42  2394.49  2301.64
# 9   10860.02  10186.25  9164.70  8355.20  3937.08  3290.00  6600.56  6225.65
# 10  10066.85  10860.02  8598.35  8434.38  5377.61  3937.08  6325.49  5475.39
# 11   9423.08  10066.85  7939.57  7714.90  3926.82  5377.61  5582.63  4500.57
#
#     Day  Season      L(T)
# 0   1.0     2.0   5604.93
# 5   1.0     2.0   7279.38
# 9   1.0     2.0  10066.85
# 10  1.0     2.0   9423.08
# 11  1.0     2.0   8588.13

# %%
load_data.describe()
# Out:
#              L(T-1)        L(T-2)       L(T-24)       L(T-48)       P(T-1)  \
# count     46.000000     46.000000     46.000000     46.000000    46.000000
# mean    7911.015435   7846.354130   7808.661304   7612.593696  3162.335435
# std     1849.131941   2046.185817   1593.738570   1603.149756  1184.313345
# min     4186.780000   3968.730000   4762.830000   4574.500000  1577.500000
# 25%     6403.270000   5842.710000   6415.195000   6249.692500  2007.397500
# 50%     8384.255000   8432.830000   7913.110000   7713.400000  3060.985000
# 75%     9390.672500   9454.910000   9190.035000   8759.810000  3934.515000
# max    10860.020000  10860.020000  10310.500000  10217.730000  5947.600000
#
#             P(T-2)      P(T-24)      P(T-48)        Day  Season          L(T)
# count    46.000000    46.000000    46.000000  46.000000    46.0     46.000000
# mean   3112.452609  3223.465217  3272.385000   0.217391     2.0   7964.141957
# ...

# %% [markdown]
# #Data Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()
load_data_norm=ms.fit_transform(load_data)
print(load_data_norm)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
load_data_ss=ss.fit_transform(load_data)
print(load_data_ss)

# %% [markdown]
# #Data Split

# %%
dataset=pd.DataFrame(data=load_data_norm[0:,0:])
dataset.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.099670  0.049512  0.089082  0.000000  0.168479  0.176212  0.152280
# 1  0.362545  0.339787  0.354572  0.342655  0.086071  0.055741  0.165406
# 2  1.000000  0.902229  0.793463  0.669953  0.539937  0.394169  1.000000
# 3  0.881142  1.000000  0.691375  0.683984  0.869570  0.541678  0.945419
# 4  0.784671  0.884903  0.572626  0.556490  0.537590  0.870064  0.798016
#
#          7    8    9         10
# 0  0.143264  1.0  0.0  0.154816
# 1  0.146445  1.0  0.0  0.450034
# 2  0.925561  1.0  0.0  0.941487
# 3  0.776596  1.0  0.0  0.827985
# 4  0.583045  1.0  0.0  0.680777

# %%
X=dataset.iloc[:,0:10].values
Y=dataset.iloc[:,10:].values
print(X)
print(Y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
print(y_test[0:5])
print(X_test.shape)
print(X_train.shape)
# Out:
# [[0.2118373 ]
#  [0.04148522]
#  [0.99518151]
#  [0.68077716]
#  [0.1378762 ]]
# (10, 10)
# (36, 10)

# %% [markdown]
# # Thank You
